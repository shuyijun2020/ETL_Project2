# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import psycopg2

# %% [markdown]
# ### Source: Kaggle
# * https://www.kaggle.com/tobycrabtree/nfl-scores-and-betting-data
# * downloaded teams, scores, and stadiums data from Kaggle

# %%
# Files to Load 
team_df = pd.read_csv('teams.csv')
stadium_data = pd.read_csv('stadiums.csv')
score_data = pd.read_csv('scores.csv')

# %% [markdown]
# ### NFL Teams
# * The National Football League (NFL) is a professional American football league consisting of 32 teams, divided equally between the National Football Conference (NFC) and the American Football Conference (AFC).

# %%
team_df.drop(['team_id_pfr'],axis='columns',inplace=True)

# %%
team_df = team_df.replace(np.nan, '', regex=True)
team_df.head()
# Out:
#              team_name team_name_short team_id team_conference team_division  \
# 0    Arizona Cardinals       Cardinals     ARI             NFC      NFC West
# 1    Phoenix Cardinals       Cardinals     ARI             NFC
# 2  St. Louis Cardinals       Cardinals     ARI             NFC
# 3      Atlanta Falcons         Falcons     ATL             NFC     NFC South
# 4     Baltimore Ravens          Ravens     BAL             AFC     AFC North
#
#   team_conference_pre2002 team_division_pre2002
# 0                     NFC              NFC West
# 1                     NFC              NFC East
# 2                     NFC              NFC East
# 3                     NFC              NFC West
# 4                     AFC           AFC Central

# %%
team_df.set_index("team_name", inplace=True)
team_df.head()
# Out:
#                     team_name_short team_id team_conference team_division  \
# team_name
# Arizona Cardinals         Cardinals     ARI             NFC      NFC West
# Phoenix Cardinals         Cardinals     ARI             NFC
# St. Louis Cardinals       Cardinals     ARI             NFC
# Atlanta Falcons             Falcons     ATL             NFC     NFC South
# Baltimore Ravens             Ravens     BAL             AFC     AFC North
#
#                     team_conference_pre2002 team_division_pre2002
# team_name
# Arizona Cardinals                       NFC              NFC West
# Phoenix Cardinals                       NFC              NFC East
# St. Louis Cardinals                     NFC              NFC East
# Atlanta Falcons                         NFC              NFC West
# Baltimore Ravens                        AFC           AFC Central

# %%
team_df.dtypes
# Out:
# team_name_short            object
# team_id                    object
# team_conference            object
# team_division              object
# team_conference_pre2002    object
# team_division_pre2002      object
# dtype: object

# %% [markdown]
# ### List of current National Football League stadiums
# * Stadiums represent a considerable expense to a community, and thus their construction, use, and funding often enter the public discourse.[1] Also, given the perceived advantage a team gets to playing in its home stadium, particular attention is given in the media to the peculiarities of each stadium's environment. Climate, playing surface (either natural or artificial turf), and the type of roof all contribute to giving each team its home-field advantage.
#
# * Stadiums are either open, enclosed, or have a retractable roof. For retractable roofs, the home team determines if the roof is to be opened or closed 90 minutes before kickoff. The roof remains open unless precipitation or lightning is within the vicinity of the stadium, the temperature drops below 40 °F (4 °C), or wind gusts are greater than 40 miles per hour (64 km/h), in which case the roof operators will close the roof.[2]

# %%
# create a list of columns that you are considering to keep
stadium_cols = ['stadium_name', 'stadium_location', 'stadium_type', 'stadium_weather_type', 'stadium_capacity']

# create a new dataframe from the original
stadium_df = stadium_data[stadium_cols].copy()
stadium_df.head()
# Out:
#         stadium_name   stadium_location stadium_type stadium_weather_type  \
# 0         Alamo Dome    San Antonio, TX       indoor                 dome
# 1     Alltel Stadium   Jacksonville, FL          NaN                  NaN
# 2     Alumni Stadium  Chestnut Hill, MA      outdoor                 cold
# 3    Anaheim Stadium        Anaheim, CA      outdoor                 warm
# 4  Arrowhead Stadium    Kansas City, MO      outdoor                 cold
#
#   stadium_capacity
# 0            72000
# 1              NaN
# 2              NaN
# 3              NaN
# 4           76,416

# %%
# extract city and state from stadium location and add them as separate columns
def get_city(stadium_location):
    return stadium_location.split(",")[0]

def get_state(stadium_location):
    return stadium_location.split(",")[1]

stadium_df['city'] = stadium_df['stadium_location'].apply(lambda x: f"{get_city(x)}")
stadium_df['state'] = stadium_df['stadium_location'].apply(lambda x: f"{get_state(x)}")
stadium_df.head()
# Out:
#         stadium_name   stadium_location stadium_type stadium_weather_type  \
# 0         Alamo Dome    San Antonio, TX       indoor                 dome
# 1     Alltel Stadium   Jacksonville, FL          NaN                  NaN
# 2     Alumni Stadium  Chestnut Hill, MA      outdoor                 cold
# 3    Anaheim Stadium        Anaheim, CA      outdoor                 warm
# 4  Arrowhead Stadium    Kansas City, MO      outdoor                 cold
#
#   stadium_capacity           city state
# 0            72000    San Antonio    TX
# 1              NaN   Jacksonville    FL
# 2              NaN  Chestnut Hill    MA
# 3              NaN        Anaheim    CA
# 4           76,416    Kansas City    MO

# %%
# drop stadium_laction
stadium_df.drop(['stadium_location'],axis='columns',inplace=True)
stadium_df.head()
# Out:
#         stadium_name stadium_type stadium_weather_type stadium_capacity  \
# 0         Alamo Dome       indoor                 dome            72000
# 1     Alltel Stadium          NaN                  NaN              NaN
# 2     Alumni Stadium      outdoor                 cold              NaN
# 3    Anaheim Stadium      outdoor                 warm              NaN
# 4  Arrowhead Stadium      outdoor                 cold           76,416
#
#             city state
# 0    San Antonio    TX
# 1   Jacksonville    FL
# 2  Chestnut Hill    MA
# 3        Anaheim    CA
# 4    Kansas City    MO

# %%
# set index to stadium_name
stadium_df.set_index("stadium_name", inplace=True)
stadium_df.tail()
# Out:
#                      stadium_type stadium_weather_type stadium_capacity  \
# stadium_name
# War Memorial Stadium      outdoor                 cold              NaN
# Wembley Stadium           outdoor             moderate              NaN
# Wrigley Field             outdoor                 cold              NaN
# Yale Bowl                 outdoor                 cold              NaN
# Yankee Stadium            outdoor                 cold              NaN
#
#                            city state
# stadium_name
# War Memorial Stadium    Buffalo    NY
# Wembley Stadium          London    UK
# Wrigley Field           Chicago    IL
# Yale Bowl             New Haven    CT
# Yankee Stadium            Bronx    NY

# %%
stadium_df.head()
# Out:
#                   stadium_type stadium_weather_type stadium_capacity  \
# stadium_name
# Alamo Dome              indoor                 dome            72000
# Alltel Stadium             NaN                  NaN              NaN
# Alumni Stadium         outdoor                 cold              NaN
# Anaheim Stadium        outdoor                 warm              NaN
# Arrowhead Stadium      outdoor                 cold           76,416
#
#                             city state
# stadium_name
# Alamo Dome           San Antonio    TX
# Alltel Stadium      Jacksonville    FL
# Alumni Stadium     Chestnut Hill    MA
# Anaheim Stadium          Anaheim    CA
# Arrowhead Stadium    Kansas City    MO

# %% [markdown]
# ### Scores
#
# * Scores for all the teams since 1966

# %%
# create a list of columns that you are considering to keep
score_cols = ['schedule_season', 'schedule_week', 'schedule_playoff', 'team_home', 'score_home', 
              'score_away', 'team_away',  'stadium']

# create a new dataframe from original
score_df = score_data[score_cols].copy()

score_df
# Out:
#        schedule_season schedule_week  schedule_playoff            team_home  \
# 0                 1966             1             False       Miami Dolphins
# 1                 1966             1             False       Houston Oilers
# 2                 1966             1             False   San Diego Chargers
# 3                 1966             2             False       Miami Dolphins
# 4                 1966             1             False    Green Bay Packers
# ...                ...           ...               ...                  ...
# 12673             2019      Division              True    Green Bay Packers
# 12674             2019      Division              True   Kansas City Chiefs
# 12675             2019    Conference              True   Kansas City Chiefs
# 12676             2019    Conference              True  San Francisco 49ers
# 12677             2019     Superbowl              True   Kansas City Chiefs
#
#        score_home  score_away            team_away            stadium
# 0              14          23      Oakland Raiders        Orange Bowl
# 1              45           7       Denver Broncos       Rice Stadium
# 2              27           7        Buffalo Bills     Balboa Stadium
# 3              14          19        New York Jets        Orange Bowl
# 4              24           3      Baltimore Colts      Lambeau Field
# ...           ...         ...                  ...                ...
# 12673          28          23     Seattle Seahawks      Lambeau Field
# 12674          51          31       Houston Texans  Arrowhead Stadium
# 12675          35          24     Tennessee Titans  Arrowhead Stadium
# 12676          37          20    Green Bay Packers     Levi's Stadium
# 12677          31          20  San Francisco 49ers  Hard Rock Stadium
#
# [12678 rows x 8 columns]

# %%
# add the winner column based on scores between home team and opponent
score_df['winner'] = np.where(score_df['score_home'] > score_df['score_away'], score_df['team_home'], score_df['team_away']) 
score_df.head()
# Out:
#    schedule_season schedule_week  schedule_playoff           team_home  \
# 0             1966             1             False      Miami Dolphins
# 1             1966             1             False      Houston Oilers
# 2             1966             1             False  San Diego Chargers
# 3             1966             2             False      Miami Dolphins
# 4             1966             1             False   Green Bay Packers
#
#    score_home  score_away        team_away         stadium              winner
# 0          14          23  Oakland Raiders     Orange Bowl     Oakland Raiders
# 1          45           7   Denver Broncos    Rice Stadium      Houston Oilers
# 2          27           7    Buffalo Bills  Balboa Stadium  San Diego Chargers
# 3          14          19    New York Jets     Orange Bowl       New York Jets
# 4          24           3  Baltimore Colts   Lambeau Field   Green Bay Packers

# %%
# add id column 
score_df['id'] = range(1, 1+len(score_df))
score_df.head()
# Out:
#    schedule_season schedule_week  schedule_playoff           team_home  \
# 0             1966             1             False      Miami Dolphins
# 1             1966             1             False      Houston Oilers
# 2             1966             1             False  San Diego Chargers
# 3             1966             2             False      Miami Dolphins
# 4             1966             1             False   Green Bay Packers
#
#    score_home  score_away        team_away         stadium  \
# 0          14          23  Oakland Raiders     Orange Bowl
# 1          45           7   Denver Broncos    Rice Stadium
# 2          27           7    Buffalo Bills  Balboa Stadium
# 3          14          19    New York Jets     Orange Bowl
# 4          24           3  Baltimore Colts   Lambeau Field
#
#                winner  id
# 0     Oakland Raiders   1
# 1      Houston Oilers   2
# 2  San Diego Chargers   3
# 3       New York Jets   4
# 4   Green Bay Packers   5

# %%
# move the id column to first place
cols = score_df.columns.tolist()
cols = cols[-1:] + cols[:-1]
score_df = score_df[cols] 
score_df.head()
# Out:
#    id  schedule_season schedule_week  schedule_playoff           team_home  \
# 0   1             1966             1             False      Miami Dolphins
# 1   2             1966             1             False      Houston Oilers
# 2   3             1966             1             False  San Diego Chargers
# 3   4             1966             2             False      Miami Dolphins
# 4   5             1966             1             False   Green Bay Packers
#
#    score_home  score_away        team_away         stadium              winner
# 0          14          23  Oakland Raiders     Orange Bowl     Oakland Raiders
# 1          45           7   Denver Broncos    Rice Stadium      Houston Oilers
# 2          27           7    Buffalo Bills  Balboa Stadium  San Diego Chargers
# 3          14          19    New York Jets     Orange Bowl       New York Jets
# 4          24           3  Baltimore Colts   Lambeau Field   Green Bay Packers

# %%
score_df.set_index("id", inplace=True)
score_df.tail()
# Out:
#        schedule_season schedule_week  schedule_playoff            team_home  \
# id
# 12674             2019      Division              True    Green Bay Packers
# 12675             2019      Division              True   Kansas City Chiefs
# 12676             2019    Conference              True   Kansas City Chiefs
# 12677             2019    Conference              True  San Francisco 49ers
# 12678             2019     Superbowl              True   Kansas City Chiefs
#
#        score_home  score_away            team_away            stadium  \
# id
# 12674          28          23     Seattle Seahawks      Lambeau Field
# 12675          51          31       Houston Texans  Arrowhead Stadium
# 12676          35          24     Tennessee Titans  Arrowhead Stadium
# 12677          37          20    Green Bay Packers     Levi's Stadium
# 12678          31          20  San Francisco 49ers  Hard Rock Stadium
#
#                     winner
# id
# 12674    Green Bay Packers
# 12675   Kansas City Chiefs
# 12676   Kansas City Chiefs
# 12677  San Francisco 49ers
# 12678   Kansas City Chiefs

# %% [markdown]
# ### Create database connection

# %%
connection_string = "postgres:postgres@localhost:5432/nfl_db"
engine = create_engine(f'postgresql://{connection_string}')

# %% [markdown]
# ### Load DataFrames into database

# %%
team_df.to_sql(name='teams', con=engine, if_exists='replace', index=True)

# %%
stadium_df.to_sql(name='stadiums', con=engine, if_exists='replace', index=True)

# %%
score_df.to_sql(name='scores', con=engine, if_exists='replace', index=True)
